# %%
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = "data/3 - Scenario SA1/xmv9_hundred_data_1.csv"
columnIndex = 4

# %%
rows = []
with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile) 
    for row in csvreader: 
        rows.append(row) 
print("Total no. of rows: %d"%(csvreader.line_num)) 
print(len(rows[0]))
train = np.array((500, 41))
thresholdData = np.array((3500, 41))
test = np.array((800, 41))
allData = np.array((4800,41))
train = np.array(rows[:500])
thresholdData = np.array(rows[500:4000])
test = np.array(rows[4000:4800])    
allData=np.array(rows[:-1])
# Out:
# Total no. of rows: 4801
# 41

# %%
print(train.shape)
print(thresholdData.shape)
print(test.shape)
print(allData.shape)
# Out:
# (500, 41)
# (3500, 41)
# (800, 41)
# (4800, 41)

# %% [markdown]
# # Training phase

# %%
n = 500 
l = 250
k = n-l+1
X = np.zeros((l,k))   # Trajectory matrix
sensorReadings = np.transpose(train)[columnIndex] # taking first 500 sensor readings to get U
trainSensorReadings = sensorReadings
print(X.shape)
for i in range(l):
    X[i]=sensorReadings[i:i+k]
# Out:
# (250, 251)

# %%
meanX = np.mean(X,axis=1) 
print(meanX.shape)
# Out:
# (250,)

# %%
# SVD for trajectory matrix
U, S, V  = np.linalg.svd(X, full_matrices=True)

# %%
print(U.shape)
print(S.shape)
print(S)
# Out:
# (250, 250)
# (250,)
# [8.06543294e+03 6.57407782e+00 6.56744709e+00 6.50176172e+00
#  6.48940193e+00 6.01278713e+00 6.00663722e+00 5.99557682e+00
#  5.95465639e+00 5.67968314e+00 5.65900178e+00 5.64285764e+00
#  5.61957485e+00 5.54766464e+00 5.54411387e+00 5.38623332e+00
#  5.36017765e+00 5.08377516e+00 5.07542378e+00 4.90695665e+00
#  4.88921599e+00 4.85856584e+00 4.84100507e+00 4.77861207e+00
#  4.76018936e+00 4.74322678e+00 4.73700580e+00 4.68855878e+00
#  4.66275044e+00 4.59446341e+00 4.55564796e+00 4.55121134e+00
#  4.52957046e+00 4.47280243e+00 4.46845603e+00 4.46345663e+00
#  4.45615354e+00 4.42751534e+00 4.41229893e+00 4.40226114e+00
#  4.34803219e+00 4.32802556e+00 4.32425881e+00 4.29735334e+00
#  4.28509944e+00 4.27732036e+00 4.26022297e+00 4.24588580e+00
#  4.19894857e+00 4.18290573e+00 4.16303582e+00 4.14280432e+00
#  4.10539594e+00 4.08379752e+00 4.06499036e+00 4.05776214e+00
#  4.05652016e+00 4.05054901e+00 4.01356471e+00 4.00692679e+00
#  3.99529241e+00 3.99132113e+00 3.97806752e+00 3.85260912e+00
#  3.82400323e+00 3.80242857e+00 3.79868576e+00 3.78738009e+00
#  3.77479655e+00 3.75814122e+00 3.74222124e+00 3.72549333e+00
#  3.71707894e+00 3.70144698e+00 3.70046395e+00 3.64000078e+00
#  3.60240776e+00 3.59923580e+00 3.59425409e+00 3.56710267e+00
#  3.53071057e+00 3.52018280e+00 3.50909966e+00 3.49587417e+00
#  3.48600626e+00 3.41222717e+00 3.40444674e+00 3.39003662e+00
#  3.38169249e+00 3.34925966e+00 3.34597557e+00 3.25453241e+00
#  3.24146201e+00 3.23452507e+00 3.20621634e+00 3.19900140e+00
#  3.18938077e+00 3.18573091e+00 3.15582400e+00 3.14382162e+00
#  3.13553105e+00 3.08241186e+00 3.08065575e+00 3.02529026e+00
#  3.01199617e+00 2.99867647e+00 2.95064451e+00 2.91263072e+00
#  2.89192122e+00 2.87179808e+00 2.84249486e+00 2.81564849e+00
#  2.80543722e+00 2.76890424e+00 2.72902692e+00 2.72189903e+00
#  2.68027227e+00 2.66566205e+00 2.66202349e+00 2.66152977e+00
#  2.64179772e+00 2.60939948e+00 2.59084443e+00 2.58340244e+00
#  2.56645031e+00 2.54310762e+00 2.52203813e+00 2.50838144e+00
#  2.50116027e+00 2.47790071e+00 2.46821852e+00 2.45250666e+00
#  2.43497745e+00 2.42036292e+00 2.40863637e+00 2.38729059e+00
#  2.36433058e+00 2.36129642e+00 2.35903655e+00 2.31168069e+00
#  2.30670289e+00 2.28148153e+00 2.27055275e+00 2.24088401e+00
#  2.22163418e+00 2.20829933e+00 2.20364279e+00 2.19434613e+00
#  2.18602131e+00 2.13661459e+00 2.10897120e+00 2.10783322e+00
#  2.08279163e+00 2.06176926e+00 2.01751387e+00 2.00005767e+00
#  1.99346889e+00 1.96019165e+00 1.95789083e+00 1.92646025e+00
#  1.91183809e+00 1.90713129e+00 1.90093785e+00 1.87599465e+00
#  1.85920541e+00 1.85240546e+00 1.82939175e+00 1.79936360e+00
#  1.78368753e+00 1.77255547e+00 1.76883884e+00 1.75517386e+00
#  1.74360258e+00 1.68791779e+00 1.68119147e+00 1.67348414e+00
#  1.59994096e+00 1.57596135e+00 1.55852885e+00 1.54686851e+00
#  1.53789653e+00 1.52950720e+00 1.52119117e+00 1.51795746e+00
#  1.49437143e+00 1.48663484e+00 1.47408426e+00 1.43305821e+00
#  1.42290446e+00 1.42051171e+00 1.41353610e+00 1.38433077e+00
#  1.33366515e+00 1.32960740e+00 1.30311099e+00 1.28939058e+00
#  1.24273608e+00 1.21876368e+00 1.19338533e+00 1.18483826e+00
#  1.15347962e+00 1.13238788e+00 1.10414833e+00 1.08427636e+00
#  1.06277092e+00 1.05287368e+00 9.71442527e-01 9.60861323e-01
#  9.51229104e-01 9.49042203e-01 9.37687371e-01 9.36475338e-01
#  9.18666931e-01 9.13922338e-01 8.89537345e-01 8.80345296e-01
#  8.74517788e-01 8.55028238e-01 8.47414193e-01 8.05545299e-01
#  7.90415948e-01 7.85752173e-01 7.54569527e-01 7.41039281e-01
#  7.25883409e-01 6.91861937e-01 6.81570917e-01 6.65624758e-01
#  6.63870939e-01 6.59952970e-01 6.46188806e-01 6.32716742e-01
#  6.06551627e-01 5.91891621e-01 5.55311274e-01 5.27648545e-01
#  5.15757727e-01 5.05483815e-01 4.60768526e-01 4.03535617e-01
#  3.61911040e-01 3.61051640e-01 3.55037369e-01 2.27410876e-01
#  1.59155989e-01 1.28108405e-01 1.25240665e-01 6.26732950e-02
#  5.40613032e-02 2.22121693e-02]

# %%
#choose r=1 
newU = U[:,0:1]

# %%
print(newU.shape)
# Out:
# (250, 1)

# %% [markdown]
# # Determining theta (threshold)

# %%
n = 3500
k = n-l+1
X = np.zeros((l,k))
sensorReadings = np.transpose(thresholdData)[columnIndex]
thresholdSensorReadings = sensorReadings
# print(len(sensorReadings))
print(X.shape)
for i in range(l):
    X[i]=sensorReadings[i:i+k]
# Out:
# (250, 3251)

# %%
projectedCentre = np.dot(newU.T,meanX)  #finding projection for meanX
print(projectedCentre)
# Out:
# [-509.08560958]

# %%
departureScores=np.zeros((k,1)) # departure scores for lag vectors
for i in range(k):
    x_i=np.array([X[j][i] for j in range(l)])
    departureScores[i] = np.dot(projectedCentre - np.dot(newU.T,x_i),projectedCentre - np.dot(newU.T,x_i))

# %%
print(departureScores.shape)
# Out:
# (3251, 1)

# %%
print(max(departureScores))
# Out:
# [0.22951338]

# %%
threshold = max(departureScores) + 0.01 # setting threshold as max of departure score + small constant

# %% [markdown]
# # Testing phase

# %%
n = 800
k = n-l+1
X = np.zeros((l,k))
testSensorReadings = np.transpose(test)[columnIndex]
print(len(testSensorReadings))
print(X.shape)
for i in range(l):
    X[i] = testSensorReadings[i:i+k]
# Out:
# 800
# (250, 551)

# %%
testDepartureScores = np.zeros((k,1))
for i in range(k):
    x_i = np.array([X[j][i] for j in range(l)])
    testDepartureScores[i] = np.dot(projectedCentre - np.dot(newU.T,x_i), projectedCentre - np.dot(newU.T,x_i))
print(testDepartureScores.shape)
# Out:
# (551, 1)

# %% [markdown]
# # Plot of departure scores

# %%
n = 4800
k = n-l+1
X = np.zeros((l,k))
testSensorReadings = np.transpose(allData)[columnIndex]
print(X.shape)
for i in range(l):
    X[i] = testSensorReadings[i:i+k]
finalDepartureScores = np.zeros((k,1))
for i in range(k):
    x_i = np.array([X[j][i] for j in range(l)])
    finalDepartureScores[i] = np.dot(projectedCentre - np.dot(newU.T,x_i), projectedCentre - np.dot(newU.T,x_i))
print(finalDepartureScores.shape)
# Out:
# (250, 4551)
# (4551, 1)

# %%
x=[i for i in range(250,4801)]
fig = plt.figure(figsize=(15,5))
plt.plot(x,finalDepartureScores , 'b-', linewidth=1, label='Departure score')
locs = [500,1000,1500,2000,2500,3000,3500,4000,4500,5000]
xlabels = [locs[i]/100 for i in range(len(locs))]
plt.xticks(locs, xlabels)
plt.xlabel('Time(Hours)')
plt.ylabel('Departure Score')
plt.margins(x=0)
plt.hlines(threshold, 0, 5000, linestyles='dashed', label='Alarm Threshold')
plt.vlines(4000, 0,max(testDepartureScores) , linestyles='dashed', colors='red', label='Start of testing phase')
plt.axvspan(4000, 5000, alpha=0.5, color='red')
plt.title('Departure score for XMEAS(5) in SA(1)')
plt.legend()
plt.show()

# %% [markdown]
# # Plot of all readings for XMEAS(5) sensor

# %%
x1 = [i for i in range(500)]
x2 = [i for i in range(500,4000)]
x3 = [i for i in range(4000,4800)]
fig = plt.figure(figsize=(15,5))
sensorReadings = np.transpose(allData)[columnIndex]
plt.plot(x1, sensorReadings[:500], 'b-',label='Training')
plt.plot(x2, sensorReadings[500:4000],'k-' , label = 'Threshold finding')
plt.plot(x3, sensorReadings[4000:4800],'r-',label = 'Detection')
locs = [500,1000,1500,2000,2500,3000,3500,4000,4500,5000]
xlabels = [locs[i]/100 for i in range(len(locs))]
plt.xticks(locs, xlabels)
plt.xlabel('Time(Hours)')
plt.ylabel('XMEAS (5)')
plt.title('Sensor readings for XMEAS(5) in SA(1)')
plt.legend()
plt.show()
